# %% [markdown]
# <a href="https://colab.research.google.com/github/isha409/isha/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: load the libs for EDA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# prompt: load the data

import pandas as pd
# Assuming the data is in a CSV file named 'data.csv' in your current directory.
# Replace 'data.csv' with the actual file name and path if needed.
try:
  data = pd.read_csv('/content/archive.zip')
  print("Data loaded successfully.")
  # You can now work with the 'data' DataFrame. For example:
  # print(data.head())
except FileNotFoundError:
  print("Error: 'data.csv' not found. Please make sure the file exists in the correct location.")
except pd.errors.EmptyDataError:
  print("Error: 'data.csv' is empty.")
except pd.errors.ParserError:
  print("Error: Could not parse 'data.csv'. Please check the file format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Data loaded successfully.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
data.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
data.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
# prompt: check  missing duplicate values of the data

# Check for missing values
missing_values = data.isnull().sum()
print("Missing values:\n", missing_values)

# Check for duplicate rows
duplicate_rows = data.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_rows)

# Display duplicate rows (optional)
# duplicate_rows_df = data[data.duplicated(keep=False)]
# print("\nDuplicate rows:\n", duplicate_rows_df)


# Analyze specific columns for duplicates (example with 'column_name')
# Replace 'column_name' with the actual column you want to check
# duplicate_in_column = data['column_name'].duplicated().sum()
# print(f"\nNumber of duplicates in 'column_name': {duplicate_in_column}")

# Handle missing values (example: fill with mean)
# data['column_with_missing_values'].fillna(data['column_with_missing_values'].mean(), inplace=True)

# Handle duplicate rows (example: remove duplicates)
# data.drop_duplicates(inplace=True)
# Out:
# Missing values:
#  ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64
#
# Number of duplicate rows: 0

# %%
# prompt: clean the data

import pandas as pd
import numpy as np
# Handle missing values (example: fill with mean for numerical, mode for categorical)
for col in data.columns:
    if pd.api.types.is_numeric_dtype(data[col]):
        data[col].fillna(data[col].mean(), inplace=True)
    elif pd.api.types.is_categorical_dtype(data[col]):
        data[col].fillna(data[col].mode()[0], inplace=True)
    else:
      #Handle other data types as needed (e.g., string imputation)
      data[col].fillna('Unknown', inplace=True)


# Remove duplicate rows
data.drop_duplicates(inplace=True)

#Check for inconsistent data types
for col in data.columns:
    print(f"Column '{col}': {data[col].dtype}")

# Convert data types if needed
# Example: Convert a column to datetime
# data['date_column'] = pd.to_datetime(data['date_column'], errors='coerce')

# Example: Convert a column to numeric, coercing errors to NaN
# data['numeric_column'] = pd.to_numeric(data['numeric_column'], errors='coerce')

#Outlier handling (example: using IQR method)
#for col in data.select_dtypes(include=np.number):
#    Q1 = data[col].quantile(0.25)
#    Q3 = data[col].quantile(0.75)
#    IQR = Q3 - Q1
#    lower_bound = Q1 - 1.5 * IQR
#    upper_bound = Q3 + 1.5 * IQR
#    data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]


#Re-check for missing values and duplicates after cleaning
missing_values_after_cleaning = data.isnull().sum()
print("Missing values after cleaning:\n", missing_values_after_cleaning)

duplicate_rows_after_cleaning = data.duplicated().sum()
print("\nNumber of duplicate rows after cleaning:", duplicate_rows_after_cleaning)

data.info()
data.describe()
data.head()
# Out:
# Column 'ID': int64
# Column 'Name': object
# Column 'Age': int64
# Column 'Nationality': object
# Column 'Overall': int64
# Column 'Potential': int64
# Column 'Club': object
# Column 'Value': float64
# Column 'Wage': float64
# Column 'Preferred Foot': object
# Column 'International Reputation': float64
# Column 'Skill Moves': float64
# Column 'Position': object
# Column 'Joined': int64
# Column 'Contract Valid Until': object
# Column 'Height': float64
# Column 'Weight': float64
# Column 'Release Clause': float64
# Missing values after cleaning:
#  ID                          0
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# ...

# %%
# prompt: perform data visualization properly of the clean data

import matplotlib.pyplot as plt
# Assuming 'data' DataFrame is already cleaned as in the previous code.

# Example visualizations:

# 1. Histogram for a numerical column:
plt.figure(figsize=(8, 6))
sns.histplot(data['Item_Weight'], kde=True)  # Replace 'Item_Weight' with your numerical column
plt.title('Distribution of Item Weights')
plt.xlabel('Item Weight')
plt.ylabel('Frequency')
plt.show()

# 2. Box plot for a numerical column:
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Item_Outlet_Sales'])  # Replace 'Item_Outlet_Sales' with your numerical column
plt.title('Box Plot of Item Outlet Sales')
plt.show()

# 3. Count plot for a categorical column:
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Outlet_Location_Type'])  # Replace 'Outlet_Location_Type' with your categorical column
plt.title('Number of Outlets by Location Type')
plt.xlabel('Outlet Location Type')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.show()


# 4. Scatter plot for relationship between two numerical columns:
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Item_Weight', y='Item_Outlet_Sales', data=data) # Example columns, replace as needed
plt.title('Relationship between Item Weight and Item Outlet Sales')
plt.xlabel('Item Weight')
plt.ylabel('Item Outlet Sales')
plt.show()

# 5. Pairplot for multiple numerical columns:
#sns.pairplot(data[['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']]) # Example columns, replace as needed
#plt.show()


# 6. Heatmap for correlation between numerical columns:
plt.figure(figsize=(12, 8))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# Add more visualizations as needed based on your data and analysis goals.
# Remember to replace placeholder column names with the actual names from your dataset.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item_Weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-e3c260a04e8f> in <cell line: 0>()
#       8 # 1. Histogram for a numerical column:
# ...

# %%
# prompt: perform data Visualization

import matplotlib.pyplot as plt
# Assuming the correct column name is 'ItemOutletSales' - adjust if needed
sales_column_name = 'Item_Outlet_Sales'  # Replace with the actual column name

# Visualizations
plt.figure(figsize=(10, 6))
# Use the sales_column_name variable to access the column
sns.histplot(data[sales_column_name], kde=True)
plt.title('Distribution of Item Outlet Sales')
plt.xlabel('Item Outlet Sales')
plt.ylabel('Frequency')
plt.show()


# Box plot to visualize the distribution of a numerical column
plt.figure(figsize=(8, 6))
# Use the sales_column_name variable here as well
sns.boxplot(x='Item_Type', y=sales_column_name, data=data)
plt.title('Item Outlet Sales by Item Type')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()


# Scatter plot to show the relationship between two numerical columns
plt.figure(figsize=(8, 6))
# Use the sales_column_name variable here too
sns.scatterplot(x='Item_MRP', y=sales_column_name, data=data)
plt.title('Item MRP vs. Item Outlet Sales')
plt.show()


# Pairplot to visualize relationships between multiple numerical columns
#sns.pairplot(data[['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']])
#plt.show()


#Heatmap of correlation between numerical features

plt.figure(figsize=(12,8))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# Bar plot for categorical features
plt.figure(figsize=(10,6))
item_type_counts = data['Item_Type'].value_counts()
sns.barplot(x=item_type_counts.index, y=item_type_counts.values)
plt.title('Item Type Counts')
plt.xticks(rotation=90)
plt.xlabel('Item Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item_Outlet_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-8d8345e3a6b0> in <cell line: 0>()
#       8 plt.figure(figsize=(10, 6))
# ...
